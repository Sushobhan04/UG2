# %%
# %matplotlib inline
import h5py
import numpy as np
import os
from UG2.utils import data as data_utils
from UG2.utils import image as image_utils
from UG2.config import Config
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import scipy.ndimage as im
import time
from UG2 import main

# %%
dataset_path         = "/data/UG2_data/datasets/BSD100_SR"
data_path            = "/data/UG2_data/"
traindedModels_path  = "/data/UG2_data/trainedModels/"

# %%
## create blurred-dataset 
kernel_blurring_flag= True
num_images          = 100
scale_factor        = 2
flags = [1, 1]
gaussian_blur_range = [0.1, 2.5]
motion_blur_range = [0, 5]
nTK = 4


source_dataset_name        = "BSD"
augmented_dataset_name = source_dataset_name + "_nTK_" + str(nTK) + "_flag_" + "_".join([str(f) for f in flags])

# label = None

# %%
with h5py.File(os.path.join(data_path, source_dataset_name + ".h5"),'r') as file:
    label = np.array(file["label"])
    
gen_data, gen_label = image_utils.blur_images(label, nTK, scale_factor, flags, gaussian_blur_range, motion_blur_range)

data_utils.create_h5(gen_data, gen_label, data_path, augmented_dataset_name + ".h5")

# %%
print(augmented_dataset_name)
# Out:
# BSD_nTK_4_flag_1_1

# %%
plt.figure()
plt.imshow(np.transpose(gen_data[4,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_label[4,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_data[8,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_label[8,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_data[12,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_label[12,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_data[16,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
plt.figure()
plt.imshow(np.transpose(gen_label[16,:].astype(np.uint8), (1, 2, 0)))
plt.colorbar()
