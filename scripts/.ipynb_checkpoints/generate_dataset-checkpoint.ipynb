# %%
# %matplotlib inline
import h5py
import numpy as np
import os
from UG2.utils import data as data_utils
from UG2.utils import image as image_utils
from UG2.config import Config
import matplotlib.pyplot as plt 
import torch
import torch.nn as nn
from torch.autograd import Variable
import scipy.ndimage as im
import time 
from UG2 import main
# Out:
# Traceback (most recent call last):
#
#   File "/home/snagesh/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-e21da2fee73b>", line 5, in <module>
#     from UG2.utils import data as data_utils
#
#   File "/home/snagesh/git/UG2/utils/data.py", line 10, in <module>
#     from UG2.utils import image as image_utils
#
#   File "/home/snagesh/git/UG2/utils/image.py", line 114
#     def blur_images(images, nTK, scale_factor, flags = [1, 1], gaussian_blur_range = (0, 1),blurSeed):
#                    ^
# SyntaxError: non-default argument follows default argument

# %%
destination_path     = "/data/UG2_data/h5Files/"
data_source_path     = "/data/UG2_data/imagenet_new_cropped/"

# %%
## create blurred-dataset 
patch_size          = np.array([224,224])
source_name_files   = []
kernel_blurring_flag= True
num_files           = 62
scale_factor        = 1
flags               = [0, 1]
gaussian_blur_range = [0.1, 2.5]
nTK                 = 1
image_format        = ".h5" 
blur_Seed           = "FixedSeed"

# %%
source_name_files   = []
if image_format == ".png":
    for i in range(num_files):
        source_name_files.append("img_"+"%03d"%(i+1)+"_SRF_2_HR")
else:
    for i in range(num_files):
        source_name_files.append("imagenet_"+str(i+1))
        
blur_parameters = {}

blur_parameters["nTK"]                  = nTK
blur_parameters["scale_factor"]         = scale_factor
blur_parameters["flags"]                = flags
blur_parameters["gaussian_blur_range"]  = gaussian_blur_range

if image_format == ".png":
    dataset_name        = "imagenet"+"_nTK_"+str(nTK)+ "_flag_" + "_".join([str(f) for f in flags])+"factor"+str(scale_factor)+"nFile"+str(i)+blurSeed
    data_utils.create_dataset(data_source_path, source_name_files, image_format, destination_path, dataset_name, num_files, patch_size, blur_parameters)
    print("h5File created: "+destination_path+dataset_name+".h5")
else:
    for i in range(num_files):
        dataset_name        = "imagenet"+"_nTK_"+str(nTK)+ "_flag_" + "_".join([str(f) for f in flags])+"factor"+str(scale_factor)+"nFile"+str(i+1)+blurSeed
        data_utils.create_dataset(data_source_path, source_name_files[i], image_format, destination_path, dataset_name, num_files, patch_size, blur_parameters)
        print("h5File created: "+destination_path+dataset_name+".h5")
# Out:
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile1RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile2RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile3RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile4RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile5RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile6RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile7RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile8RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile9RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile10RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile11RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile12RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile13RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile14RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile15RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile16RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile17RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile18RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile19RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile20RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile21RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile22RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile23RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile24RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile25RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile26RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile27RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile28RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile29RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile30RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile31RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile32RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile33RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile34RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile35RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile36RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile37RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile38RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile39RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile40RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile41RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile42RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile43RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile44RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile45RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile46RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile47RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile48RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile49RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile50RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile51RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile52RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile53RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile54RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile55RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile56RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile57RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile58RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile59RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile60RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile61RandomSeed.h5
# Number of images in the dataset: 2000
# data of shape  (2000, 3, 224, 224) and label of shape  (2000, 3, 224, 224)  created of type uint8
# h5File created: /data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile62RandomSeed.h5

# %%
with h5py.File(os.path.join(destination_path, dataset_name+".h5"),'r') as file:
    data = np.array(file["data"])
    label= np.array(file["label"])
for imageIndex in range(10):
    testImage = data[imageIndex]
    testImage = np.transpose(testImage.astype(np.uint8), (1, 2, 0))
    GTImage = label[imageIndex]
    GTImage = np.transpose(GTImage.astype(np.uint8), (1, 2, 0))
    plt.figure(figsize=(15,15))
    plt.subplot(121)
    plt.imshow(GTImage)
    plt.subplot(122)
    plt.imshow(testImage)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
data_path            = "/data/UG2_data/h5Files/"
traindedModels_path  = "/data/UG2_data/trainedModels/"
kernel_blurring_flag= True
num_files           = 10
factor              = 1
patch_size          = np.array([224, 224])
epochsList          = [50]
learningRateList    = [0.01]
numberTrainingKernel= [1]
flags               = [0,1]
numberOfExperiments = len(epochsList)*len(learningRateList)
dataset_name        = "imagenet"
blurSeed            = "RandomSeed"

# %%
fileStartIndex  = 1
for fileIndex in range(fileStartIndex,num_files+1):
    config.data_files.append(os.path.join(data_path, dataset_name+"_nTK_"+str(nTK)+ "_flag_" + "_".join([str(f) for f in flags])+"factor"+str(factor)+"nFile"+str(fileIndex)+blurSeed+".h5"))

# %%
with h5py.File("/data/UG2_data/h5Files/imagenet_nTK_1_flag_0_1factor1nFile56RandomSeed.h5", "r") as file:
    data = np.array(file["data"])

print(type(data[0,0,0,0]))
# Out:
# <class 'numpy.uint8'>
